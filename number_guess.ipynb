# %%
import random

def number_guess():
    randomNumber = random.randrange(0,100)
    tries = 5

    print("I’m thinking of a number in the range 0-100. You have five tries to guess it.")
    guessed = False

    while guessed == False:
        userInput = (input(f"You have {tries} tries left. Next Guess: "))
        while not userInput.isdigit():
            print("That is not a number. Please enter a number. ")
            userInput = (input(f"You have {tries} tries left. Next Guess: "))
        userInput = int(userInput)
        tries -= 1
        if tries == 0:
            print("Your guess is incorrect. The right answer is " + str(randomNumber))
            break
        if userInput == randomNumber:
            guessed = True
            print("You are right! I was thinking of " + str(randomNumber) + "!")
        elif userInput>randomNumber:
            print(str(userInput) + " is too high.")
        elif userInput < randomNumber:
            print(str(userInput) + " is too low.")

    print("End of game")
number_guess()
# Out:
# I’m thinking of a number in the range 0-100. You have five tries to guess it.
# You have 5 tries left. Next Guess: 4
# 4 is too low.
# You have 4 tries left. Next Guess: 56
# 56 is too low.
# You have 3 tries left. Next Guess: 67
# 67 is too low.
# You have 2 tries left. Next Guess: 89
# 89 is too low.
# You have 1 tries left. Next Guess: 100
# Your guess is incorrect. The right answer is 90
# End of game

# %%
from hangman import hangman
from number_guess import number_guess

def main():
    while True:
        
        if menu() == True:
            break


def menu():
    
    

    choice = input("""
                      A: Play Hangman
                      B: Play Number guess
                      C: Exit

                      Please enter your choice: """)

    if choice == "A" or choice =="a":
        hangman()
    elif choice == "B" or choice =="b":
        number_guess()
    elif choice=="C" or choice=="c":
        return True
    else:
        print("You must only select either A or B")
        print("Please try again")
        menu()

# %%
main()
# Out:
#                       A: Play Hangman
#                       B: Play Number guess
#                       C: Exit
#
#                       Please enter your choice: f
# You must only select either A or B
# Please try again
#
#                       A: Play Hangman
#                       B: Play Number guess
#                       C: Exit
#
#                       Please enter your choice: c
#
#                       A: Play Hangman
#                       B: Play Number guess
#                       C: Exit
#
#                       Please enter your choice: a
# _ _ _ _ _ _
# You have 5 tries left. Next Guess: s
# S _ _ _ _ _
# You have 5 tries left. Next Guess: e
# S e _ _ e _
# You have 5 tries left. Next Guess: c
# S e c _ e _
# You have 5 tries left. Next Guess: r
# S e c r e _
# You have 5 tries left. Next Guess: t
# You found the word!
#
#                       A: Play Hangman
#                       B: Play Number guess
#                       C: Exit
#
#                       Please enter your choice: b
# I’m thinking of a number in the range 0-100. You have five tries to guess it.
# You have 5 tries left. Next Guess: 45
# 45 is too high.
# You have 4 tries left. Next Guess: 34
# 34 is too low.
# You have 3 tries left. Next Guess: 36
# 36 is too high.
# You have 2 tries left. Next Guess: 35
# You are right! I was thinking of 35!
# End of game
#
#                       A: Play Hangman
#                       B: Play Number guess
#                       C: Exit
#
#                       Please enter your choice: b
# I’m thinking of a number in the range 0-100. You have five tries to guess it.
# You have 5 tries left. Next Guess: 34
# 34 is too high.
# You have 4 tries left. Next Guess: 23
# 23 is too high.
# You have 3 tries left. Next Guess: 12
# 12 is too high.
# You have 2 tries left. Next Guess: 6
# 6 is too low.
# You have 1 tries left. Next Guess: 8
# Your guess is incorrect. The right answer is 10
# End of game
